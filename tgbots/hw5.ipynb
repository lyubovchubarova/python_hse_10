# %% [markdown]
# ## Домашнее задание 6
# ### Дедлайн - 18 апреля 23:59

# %% [markdown]
# Вам нужно написать тг-бота для онлайн-издания.
#
# Бот позволяет выбрать тематику из предложенных и выдает 5 последних статей по этой тематике. Кроме того, бот позволяет ввести кодовое слово и выдает все новости с заголовками, содержащими это слово.
#
# Данные должны быть реальными - вам нужно обкачать новости (или статьи) с сайтов газет или аналогичных онлайн-изданий.
#
# **Данные**
# Можно выбрать один из этих источников или взять свой, например, сайт Вышки.
#
# - https://ircity.ru/text/ Новости Иркутска
# - http://74vpered.ru/novosti/?start=0 Газета города Троицка Челябинской области
# - https://progorod43.ru/news Новости Вятки
# - https://nash-kislovodsk.ru/news Новости Кисловодска
# - https://kaluga24.tv/home/news Новости Калуги
# - https://kostroma.today/news/ Кострома Тудей
#
# **Вы должны сдать**
#
# - код бота
# - код краулера
# - файл со статьями, тегами и всей дополнительной информацией, которая вам пригодится (лучше от 1000 статей)
